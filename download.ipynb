# %%
import numpy as np 
import pandas as pd 
import sys, requests, shutil, os
from urllib import request, error

def download_image(url):
    response = requests.get(url, stream=True)
    with open('./train_images/image.jpg', 'wb') as out:
        shutil.copyfileobj(response.raw, out)
    del response

data = pd.read_csv('train_sample.csv')

# %%
urls = data['url'].dropna()
data.head(10)
# Out:
#                  id                                                url  \
# 0  b19a8e2a9f0459f9  https://upload.wikimedia.org/wikipedia/commons...
# 1  8f874e2cb73af059  https://upload.wikimedia.org/wikipedia/commons...
# 2  db0a6d8260b5ffaf  https://upload.wikimedia.org/wikipedia/commons...
# 3  ce777bb778304709  http://upload.wikimedia.org/wikipedia/commons/...
# 4  e6bc5d0d33e8cdef  https://upload.wikimedia.org/wikipedia/commons...
# 5  268866ece013e2a5  https://upload.wikimedia.org/wikipedia/commons...
# 6  f2357dbad96a9e4f  https://upload.wikimedia.org/wikipedia/commons...
# 7  e73e68e2485c06cc  https://upload.wikimedia.org/wikipedia/commons...
# 8  8cb3cdfa65fe2a37  https://upload.wikimedia.org/wikipedia/commons...
# 9  334ad510dd5f9dd8  https://upload.wikimedia.org/wikipedia/commons...
#
#    landmark_id
# 0        15427
# 1        47133
# 2         1924
# 3        46705
# 4       121873
# 5        62798
# 6       171772
# 7       138982
# 8       138982
# 9       121873

# %%
# remain_ids = ['07a3100d7f7f267f','07f395764041eb78','09179f4332456c95','09f27ed511d71fde','0adaac1b9295bc23','0c08a7157c924129','0ca15de4245fd95d','0d480f00fc3079db','0deb7571154fb56d','0e677aefd26fe403','0fe583c346d4ebb3','103904096e7a9f81','11bf3b2036ea028a','12b19cd3d23d5030','146ca38d5e1db437','14c0048a36c010bd','14cc463d992aa412','15892202448e4ba8','166c309de9c52fe7','1801579e9e5fc3cc','189fd14fa01990f1','1943890c32362468','19d9709e71518416','1aa88994d0fcd7b6','1b30bd4a8417fe74','1b32081bc0feeaa0','1cc574eb2d0a136f','1d463939e26e2b2e','1ed89aa9c0cd6f69','20bf79c47a04d706','214b99b540d16418','2263e2c4d11e7796','2270ac85faf0ca7d','22f5d23191c3c1db','23e05c8fd2d79b63','23e92c43f1eb4c15','248d23c8fd202cf2','24c6c1a3cec080ef','2534f086b5dfd46f','25fff6b139f4efcf','26360a894ecd6677','277df540a0b8e0cc','27b22314fb7a69cf','27b2b7ed6c73b138','28054e3b466c2c6a','282dccaf228742f2','28f96cff832debda','2983b5ebbbb1a2b9','2a276455017e15d7','2bd94c13638896d2','2c45fdc56879779a','2c952b1e2c169811','2e39a39dffb9000a','2e995f7e487226d3','2f2c8a9aea7a4092','3005dfe003aae3ce','308b9c8204d56896','32034af49d013f65','32e59c6d01026975','339312b4f2e34fbc','3413643f11b6b2ee','34175af92feee451','341fc6462c4a8cda','34904fcea0011502','3517fd7f16182c69','3684a3fa9adb9816','374ad8c58adbe7c1','37c77f9c5eac77e3','37cc7cf0d5b2e906','37d0f59feef5a39c','37d2dc1cc5acfa13','39ded2a1664cbff9','39faef31e2cd81a9','3aa2edb45003de2e','3b021856ba00f98f','3bcfa4d18879118b','3cadb8c04c1a0474','3f05c0a0551eb6f3','3f2a9858678426ad','3f751c9ca0f3b8c2','3fa0bf5eb2ee9e12','40663a8427d8832a','40680ca465258f13','409eef97f
aba06a906f6b2112','abd8a6af9fda6b0c','ac911840e67b89c6','ac9d073af954c1ff','aca59f39f8725b7a','acccf1545338c526','adad515278bbda7d','ae2c8e7857f42623','ae46cd3131f5dfd8','af914d5a995a81cf','b06fcdea6b2cf267','b1b050f7e883ed8a','b22018ce86a66d51','b2570f3b94510d54','b25add02304477c3','b2b6be6fbcd62c1b','b2d2a3d9792fae39','b2ff5e7c663fe45e','b3dfecb88394d4c8','b48e3c5323adf969','b4b7d135d989fef3','b52c5a96d93a550b','b6c16d50d34bcc2c','b787b97df3735cb2','b82eacb376018901','b8bc1d9a2ea00cd9','b8bd602f06ce879b','b90544127914be32','b9750dc825bd1e20','bab747af873f4895','bb6bf05d84a5f714','bc440c10d6e15532','bce9491d6ee668c1','be1097f3271fe182','be204974256aeae9','be501921a2b29356','bed11c4b9eef8e64','bee060835702bb26','bf69ab5cf464e997','bff53154bc23800e','c1673209ad9b3d19','c1decf2423dc7963','c52bfa5dd7fe139c','c58033efd55761c4','c68f7a45b6a9c5a2','c6ee187dc0dde3ef','c84c7f743d3173b3','c914de3692491b93','cce0f22f15c14b42','cd2ec6165f0d5252','cdf5449ce86fcb3a','ce2dba9073492aea','cf44505e4ca5fc8a','cf7c42ef3254c082','d0a368b045dddfb8','d10f498a3ed6ed04','d2696f1a62fdae60','d39cd6f3772da041','d411732f7dfe80a6','d42b644842c2714d','d4d8c32716f8b2e4','d4f03fbf19454f6a','d56f61d1f36616c5','d678e2d6dd97117b','d768526e4f39965c','d780dd97a005f9bb','d7a6d0092ffcc95d','db5e57026f5da7ac','db85ee4281018989','dbb002f44df23c79','dd0f787d27802e7b','ddbe77d53fc7ef04','de05707f372f0020','de70408890e63115','dea362524f6b7f7f','e0b7727f43803cb7','e1227dd664aec92f','e1b28671b7e29e81','e34bb18cdc32ed7d','e7e6bab0cda70192','e9241d1a52b58b08','e96bd6e8a597c913','e9c607608ff05635','e9d230a67ccd3d51','e9d840a6af387832','ea928133f16f17bb','ec42380d1cd7b0de','eee9d711673ddd9f','f05cf225ca9d2bf9','f20c7d26250a54d1','f32fa976152bb4cf','f50b033381b863ca','f55cedfa883c4b11','f580fd0ac4a5c108','f582c5632136745f','f610be8864c1de2a','f7400a855dd47e76','f77473e5e9b4bf56','f8ae47db8af09194','f997793e9ddbeb84','fa40cf03bd449654','fb55e1a63661d0dc','fc0c953d1fc544dc','fc3b24844c67fabf','fe95cae07b99a2b1','feeb669121a7f417','ff42bdd970eadf2c']
# remain_data = data.loc[data['id'].isin(remain_ids)]
# remain_urls = remain_data['url']

# for url in remain_urls:
#     if url !='None':
#         img_id = remain_data.loc[remain_data['url'] == url, 'id'].iloc[0]

#         if os.path.exists('./train_images/' + str(img_id)+'.jpg'):
#             os.remove('./train_images/' + str(img_id) + '.jpg')
#         try:
#             download_image(url)
#             print(img_id)
#             os.rename('./train_images/image.jpg', './train_images/' + str(img_id) + '.jpg')
#         except:
#             continue

for url in urls:
    if url !='None':
        img_id = data.loc[data['url'] == url, 'id'].iloc[0]
    
        if os.path.exists('./train_images/'+str(img_id)+'.jpg'):
            continue
        else:
            try:
                download_image(url)
                os.rename('./train_images/image.jpg', './train_images/' + str(img_id) + '.jpg')
            except:
                continue
